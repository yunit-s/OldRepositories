# %%
# 모듈 불러오기

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D 
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/한국SW산업협회 교육-Java 과정/파이썬 실습/cat_dog_small/train'
validation_dir = '/content/drive/MyDrive/한국SW산업협회 교육-Java 과정/파이썬 실습/cat_dog_small/validation'

# %%
# ImageDataGenerator 생성

# 모든 이미지 데이터의 값을 1/255로 scaling 하면서 augmentation
train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=40,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# Validation data에 대해서는 당연히 증식을 사용하면 안된다.
validation_datagen = ImageDataGenerator(rescale=1/255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,                    # target directory
    classes=['cats', 'dogs'],     # cats, dogs 순서로 label 0,1
                                  # (생략하면 폴더순서로 label적용)
    target_size=(150,150),        # image size scaling
    batch_size=32,                # 한번에 32개의 이미지를 가져온다. 
                                  # label에 상관없이 가져온다.
    class_mode='binary')          # 고양이와 멍멍이만 존재하므로 
                                  # 2진 분류이기 때문에 binary
                                  # 다중분류인 경우 'categorical'(기본값), 
                                  # 'sparse' 이용가능
                                  # 오토인코더처럼 입력을 target으로 하는 경우 'input'
                     
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    classes=['cats', 'dogs'],
    target_size=(150,150),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 activation='relu',
                 input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(rate=0.5))
model.add(Dense(units=512,
                activation='relu'))
model.add(Dense(units=1,
                activation='sigmoid'))

print(model.summary())

model.compile(optimizer=RMSprop(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

## keep in mind that by default, batch_size is 32 in model.fit()
## steps_per_epoch = len(X_train) // batch_size
## validation_steps = len(X_test) // batch_size

history = model.fit(train_generator,
                    steps_per_epoch=62,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=31)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dropout (Dropout)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 62/62 [==============================] - 1265s 20s/step - loss: 0.6943 - accuracy: 0.5279 - val_loss: 0.6890 - val_accuracy: 0.5393
# Epoch 2/100
# 62/62 [==============================] - 23s 369ms/step - loss: 0.6922 - accuracy: 0.5290 - val_loss: 0.6858 - val_accuracy: 0.5867
# Epoch 3/100
# 62/62 [==============================] - 23s 377ms/step - loss: 0.6871 - accuracy: 0.5417 - val_loss: 0.6751 - val_accuracy: 0.6058
# Epoch 4/100
# 62/62 [==============================] - 24s 379ms/step - loss: 0.6777 - accuracy: 0.5661 - val_loss: 0.6644 - val_accuracy: 0.6028
# Epoch 5/100
# 62/62 [==============================] - 22s 358ms/step - loss: 0.6728 - accuracy: 0.5854 - val_loss: 0.7016 - val_accuracy: 0.5091
# Epoch 6/100
# 62/62 [==============================] - 24s 395ms/step - loss: 0.6640 - accuracy: 0.5884 - val_loss: 0.6870 - val_accuracy: 0.5383
# Epoch 7/100
# 62/62 [==============================] - 24s 383ms/step - loss: 0.6550 - accuracy: 0.6169 - val_loss: 0.6499 - val_accuracy: 0.6038
# Epoch 8/100
# 62/62 [==============================] - 23s 374ms/step - loss: 0.4069 - accuracy: 0.8074 - val_loss: 0.4494 - val_accuracy: 0.7782
# Epoch 83/100
# 62/62 [==============================] - 24s 381ms/step - loss: 0.4002 - accuracy: 0.8237 - val_loss: 0.4584 - val_accuracy: 0.7863
# Epoch 84/100
# 62/62 [==============================] - 21s 343ms/step - loss: 0.4100 - accuracy: 0.8064 - val_loss: 0.4429 - val_accuracy: 0.7873
# Epoch 85/100
# 62/62 [==============================] - 23s 365ms/step - loss: 0.4005 - accuracy: 0.8155 - val_loss: 0.4729 - val_accuracy: 0.7722
# Epoch 86/100
# 62/62 [==============================] - 23s 376ms/step - loss: 0.4040 - accuracy: 0.8145 - val_loss: 0.4601 - val_accuracy: 0.7833
# Epoch 87/100
# 62/62 [==============================] - 23s 365ms/step - loss: 0.3845 - accuracy: 0.8293 - val_loss: 0.4649 - val_accuracy: 0.7913
# Epoch 88/100
# 62/62 [==============================] - 23s 379ms/step - loss: 0.3983 - accuracy: 0.8201 - val_loss: 0.4286 - val_accuracy: 0.7913
# Epoch 89/100
# 62/62 [==============================] - 23s 366ms/step - loss: 0.3956 - accuracy: 0.8206 - val_loss: 0.4612 - val_accuracy: 0.7883
# Epoch 90/100
# 62/62 [==============================] - 22s 364ms/step - loss: 0.3979 - accuracy: 0.8227 - val_loss: 0.4633 - val_accuracy: 0.7802
# Epoch 91/100
# 62/62 [==============================] - 21s 342ms/step - loss: 0.3955 - accuracy: 0.8211 - val_loss: 0.4679 - val_accuracy: 0.7823
# Epoch 92/100
# 62/62 [==============================] - 22s 363ms/step - loss: 0.3946 - accuracy: 0.8252 - val_loss: 0.4814 - val_accuracy: 0.7742
# Epoch 93/100
# 62/62 [==============================] - 21s 344ms/step - loss: 0.3782 - accuracy: 0.8364 - val_loss: 0.4946 - val_accuracy: 0.7712
# Epoch 94/100
# 62/62 [==============================] - 22s 360ms/step - loss: 0.3882 - accuracy: 0.8267 - val_loss: 0.4359 - val_accuracy: 0.8054
# Epoch 95/100
# 62/62 [==============================] - 23s 367ms/step - loss: 0.3882 - accuracy: 0.8191 - val_loss: 0.4616 - val_accuracy: 0.7812
# Epoch 96/100
# 62/62 [==============================] - 22s 358ms/step - loss: 0.3797 - accuracy: 0.8227 - val_loss: 0.4847 - val_accuracy: 0.7752
# Epoch 97/100
# 62/62 [==============================] - 22s 358ms/step - loss: 0.3764 - accuracy: 0.8211 - val_loss: 0.4368 - val_accuracy: 0.8004
# Epoch 98/100
# 62/62 [==============================] - 21s 344ms/step - loss: 0.3844 - accuracy: 0.8257 - val_loss: 0.4297 - val_accuracy: 0.7964
# Epoch 99/100
# 62/62 [==============================] - 23s 374ms/step - loss: 0.3855 - accuracy: 0.8242 - val_loss: 0.4710 - val_accuracy: 0.7823
# Epoch 100/100
# 62/62 [==============================] - 23s 379ms/step - loss: 0.3836 - accuracy: 0.8318 - val_loss: 0.4343 - val_accuracy: 0.8085
